# %% [markdown]
# # Notebook for 8/30/2021 seminar on Haliburton pmag pole
#
# The current goal of this notebook is to show the Laurentia paleomagnetic pole compilation in the Mesoproterozoic to Neoproterozoic from the older Logan Loop to the Keweenawan Track and to the younger Grenville Loop.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pmagpy.pmag as pmag
import pmagpy.ipmag as ipmag
import matplotlib
import matplotlib.colors as colors
from scipy.constants import Julian_year
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from cartopy import config
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.io.shapereader import Reader
from cartopy.feature import ShapelyFeature
Laurentia_outline = ShapelyFeature(Reader('../data/Laurentia_shape/Laurentia.shp').geometries(),
                                ccrs.PlateCarree(), facecolor = 'none', edgecolor='black')

# %% [markdown]
# ## the Laurentia APWP

# %%
poles = pd.read_csv('../data/Laurentia_poles/Laurentia_poles.csv')
poles = poles[8:]
poles
# Out:
#                Unnamed: 0                                        PoleName  \
# 8               Mackenzie                      Mackenzie dykes grand mean
# 9                 Sudbury                          Sudbury Dykes Combined
# 10             Lamp_dikes                               Lamprophyre dikes
# 11          Abitibi_dikes                                   Abitibi dykes
# 12               Osler_R1                           Osler reverse (lower)
# 13               Osler_R2                           Osler reverse (upper)
# 14             MP_lowerR1                       Mamainse lower reversed 1
# 15             MP_lowerR2                       Mamainse lower reversed 2
# 16        MP_lowerNupperR        Mamainse lower normal and upper reversed
# 17              MP_upperN                           Mamainse upper normal
# 18  Grand Portage Basalts                           Grand Portage Basalts
# 19              NSVG_nneu  North Shore Volcanic Group (upper NE sequence)
# 20              NSVG_nswu  North Shore Volcanic Group (upper SW sequence)
# 21                    SLB                        Schroeder Lutsen Basalts
# 22                    PLV                          Portage Lake Volcanics
# 23                    LST                                Lake Shore Traps
# 24                     PM                         Siemens Creek Volcanics
# 25                     MI                   Michipicoten Island Formation
# 26               Nonesuch                              Nonesuch Formation
# 27                  Freda                                 Freda Formation
# 28             Haliburton                           Haliburton Intrusions
# 29             Adirondack                            Adirondack Highlands
# 30             Lac_StJean                       Lac St. Jean Anorthosite
# 31             Whitestone                              Whitestone diorite
# 32                  Morin                              Morin Anorthosite
# 33                    UMG                            Uinta_Mountain_Group
# 34                Galeros                                         Galeros
# 35              Gunbarrel                        Tsezotene Sills Combined
# 36               Franklin                       Franklin event grand mean
#
#      SLat    SLon  PLat   PLon        A95     K     N  \
# 8   65.00  250.00   4.0  190.0   5.000000   NaN   5.0
# 9   46.30  278.60  -2.5  192.8   2.500000   NaN  52.0
# 10  48.80  273.30  58.0  223.3   9.200000  37.8  19.0
# 11  48.00  279.00  44.4  211.4  13.500000   NaN   8.0
# 12  48.80  272.34  40.9  218.6   4.800000  31.5  30.0
# 13  48.59  271.81  42.3  203.4   3.700000  24.4  64.0
# 14  47.10  275.29  49.5  227.0   5.300000  31.7  24.0
# 15  47.09  275.27  37.5  205.2   4.500000  78.6  14.0
# 16  47.07  275.26  36.1  189.7   4.900000  37.3  24.0
# 17  47.06  275.25  31.2  183.2   2.500000  94.4  34.0
# 18  47.93  270.28  46.0  201.7   6.800000  38.3  13.0
# 19  47.61  269.23  31.1  181.7   4.200000  42.2  28.0
# 20  47.20  268.50  36.9  179.3   2.100000  56.8  78.0
# 21  47.54  269.10  28.3  187.6   2.500000  50.5  65.0
# 22  47.29  271.59  27.5  182.5   2.300000  48.7  78.0
# 23  47.43  272.29  22.2  180.8   4.500000  35.0  30.0
# 24  46.50  269.80  45.8  214.0   9.200000  28.3  10.0
# 25  47.70  274.15  17.0  174.7   4.400000  48.2  23.0
# 26  46.70  270.10   7.6  178.1   5.600000   NaN  11.0
# 27  46.70  270.10   2.2  179.0   4.200000   NaN  20.0
# 28  45.00  281.40 -32.6  141.9   6.300000   NaN  17.0
# 29    NaN     NaN -23.2  147.2   6.627217   NaN   NaN
# 30    NaN     NaN -19.3  146.1  10.000000   NaN   NaN
# 31    NaN     NaN -22.0  140.6   9.000000   NaN   NaN
# 32    NaN     NaN -42.3  140.2   9.000000   NaN   NaN
# 33  40.80  250.70   0.8  161.3   4.700000   NaN   8.0
# 34    NaN     NaN  -2.1  163.0   6.000000   NaN  16.0
# 35  63.50  235.00   1.6  137.8   5.000000   NaN  17.0
# 36  73.00  275.40   6.7  162.1   3.000000   NaN  56.0
#
#                                     PolarityZone  \
# 8                                            NaN
# 9                                            NaN
# 10                             multiple polarity
# 11                             multiple polarity
# 12              Alona Bay reversed-polarity zone
# 13              Alona Bay reversed-polarity zone
# 14              Alona Bay reversed-polarity zone
# 15              Alona Bay reversed-polarity zone
# 16  Flour Bay normal and reversed polarity zones
# 17             Portage Lake normal-polarity zone
# 18              Alona Bay reversed-polarity zone
# 19             Portage Lake normal-polarity zone
# 20             Portage Lake normal-polarity zone
# 21             Portage Lake normal-polarity zone
# 22             Portage Lake normal-polarity zone
# 23             Portage Lake normal-polarity zone
# 24              Alona Bay reversed-polarity zone
# 25             Portage Lake normal-polarity zone
# 26       Portage Lake normal-polarity zone (sed)
# 27       Portage Lake normal-polarity zone (sed)
# 28                                           NaN
# 29                                           NaN
# 30                                           NaN
# 31                                           NaN
# 32                                           NaN
# 33                                           NaN
# 34                                           NaN
# 35                                           NaN
# 36                                           NaN
#
#                                               PmagRef  AgeNominal  AgeLower  \
# 8                                 Buchan et al., 2000     1267.00   1265.00
# 9            Palmer,H.C., Merz,B.A., Hayatsu,A., 1977     1237.00   1232.00
# 10                                Piispa et al., 2018     1144.00   1130.00
# 11  Ernst and Buchan (1993) and Halls et al. (2005...     1141.00   1139.00
# 12                       Swanson-Hysell et al., 2014b     1108.00   1105.15
# 13  Halls, 1974; Swanson-Hysell et al., 2014b; thi...     1105.15   1104.82
# 14                       Swanson-Hysell et al., 2014a     1109.00   1106.00
# 15                              Swanson-Hysell, 2014a     1105.00   1100.40
# 16                              Swanson-Hysell, 2014a     1100.36   1100.10
# 17                              Swanson-Hysell, 2014a     1094.00   1090.00
# 18                Books, 1968; Tauxe and Kodama, 2009     1106.00   1105.28
# 19                Books, 1972; Tauxe and Kodama, 2009     1095.00   1092.00
# 20                 Tauxe and Kodama, 2009; this study     1096.18   1093.94
# 21  Books, 1972; Tauxe and Kodama, 2009; Fairchild...     1090.00   1085.00
# 22                     Books, 1972; Hnat et al., 2006     1092.51   1091.59
# 23                                 Diehl et al., 1994     1085.47   1084.00
# 24                             Palmer and Halls, 1986     1108.00   1105.00
# 25   Palmer and Davis, 1987); Fairchild et al. (2017)     1083.95   1083.52
# 26                                 Henry et al., 1977     1080.00   1070.00
# 27                                 Henry et al., 1977     1070.00   1060.00
# 28      Warnock,A.C., Kodama,K.P., Zeitler,P.K., 2000     1015.00   1000.00
# 29    Brown and McEnroe as calculated in Halls (2015)      980.00    960.00
# 30        Buchan et al 1983 as compiled in Halls 2015     1000.00   1060.00
# 31          Ueno et al 1975 as compiled in Halls 2015      960.00    940.00
# 32     Irving et al., 1974; as compiled in Halls 2015     1000.00   1060.00
# 33                                  Weil et al., 2006      760.00    750.00
# 34                                  Weil et al., 2006      757.00    750.00
# 35        Park,J.K., Norris,D.K., Larochelle,A., 1989      778.00    776.00
# 36  Denyszyn,S.W., Halls,H.C., Davis,D.W., Evans,D...      724.00    721.00
#
#     AgeUpper                                            AgeInfo  \
# 8    1269.00                                                NaN
# 9    1242.00                                                NaN
# 10   1155.00         U-Pb perovskite and Ar-Ar phlogopite dates
# 11   1143.00                           U-Pb date on baddeleyite
# 12   1110.00  Older than 1105.15 $\pm$ 0.33 Ma Osler reverse...
# 13   1105.48  $^{\mathrm{206}}$Pb/$^{\mathrm{238}}$U date of...
# 14   1112.00  Likely older than ca. 1105 Ma given distinct h...
# 15   1109.00  Older than $^{\mathrm{206}}$Pb/$^{\mathrm{238}...
# 16   1100.61  Age constrained by $^{\mathrm{206}}$Pb/$^{\mat...
# 17   1100.00  Likely ca. 1094 Ma based on similar pole posit...
# 18   1108.00  Close to, but slightly older than, $^{\mathrm{...
# 19   1098.00  Younger than the the Devil's Kettle Rhyolite $...
# 20   1096.75  $^{\mathrm{206}}$Pb/$^{\mathrm{238}}$U date on...
# 21   1091.50  $^{\mathrm{206}}$Pb/$^{\mathrm{238}}$U date of...
# 22   1093.37  $^{\mathrm{206}}$Pb/$^{\mathrm{238}}$U dates o...
# 23   1091.00  Younger than Greenstone Flow, $^{\mathrm{206}}...
# 24   1111.00  Older than the $^{\mathrm{207}}$Pb/$^{\mathrm{...
# 25   1084.39  $^{\mathrm{206}}$Pb/$^{\mathrm{238}}$U dates o...
# 26   1083.50  Likely younger than Michipicoten Island Format...
# 27   1083.50  Data come from lowermost Freda Formation. Inte...
# 28   1030.00                                                NaN
# 29   1030.00  From Brown and McEnroe (2012): " cooling curve...
# 30    960.00  Poorly constrained; giving full Grenvillian range
# 31    980.00  From Brown and McEnroe (2012): "The Whitestone...
# 32    960.00  From Brown and McEnroe (2012): "North of the A...
# 33    770.00  Correlation with Chuar Group (Dehler et al., 2...
# 34    782.00  Maximum is DZ from Dehler et al., 2017; 757 is...
# 35    780.00                                                NaN
# 36    727.00                                                NaN
#
#                                            AgeRef  Gaussian_2sigma  \
# 8                                             NaN              NaN
# 9                                             NaN              NaN
# 10                            Queen et al. (1996)              NaN
# 11                              Krogh et al. 1987              NaN
# 12          Davis and Sutcliffe, 1985; this study              NaN
# 13                                     this study             0.33
# 14                                            NaN              NaN
# 15                          Swanson-Hysell, 2014a              NaN
# 16                          Swanson-Hysell, 2014a             0.25
# 17                                            NaN              NaN
# 18                                     this study              NaN
# 19  Davis and Green, 1997; Fairchild et al., 2017              NaN
# 20                                     this study             1.12
# 21                         Fairchild et al., 2017              NaN
# 22                                     this study             0.89
# 23             Fairchild et al., 2017; this study              NaN
# 24                          Davis and Green, 1997              NaN
# 25                         Fairchild et al., 2017             0.44
# 26                                            NaN              NaN
# 27                                            NaN              NaN
# 28                                            NaN              NaN
# 29                                            NaN              NaN
# 30                                            NaN              NaN
# 31                                            NaN              NaN
# 32                                            NaN              NaN
# 33                                            NaN              NaN
# 34                                            NaN              NaN
# 35                                            NaN              NaN
# 36                                            NaN              NaN
#
#    GaussianOrUniform    Q    color
# 8                NaN  NaN      NaN
# 9                NaN  NaN      NaN
# 10               NaN  NaN      NaN
# 11               NaN  NaN      NaN
# 12           uniform  7.0  #B82431
# 13          gaussian  7.0  #F2A07E
# 14           uniform  7.0  #930E26
# 15           uniform  7.0  #F8C1A6
# 16          gaussian  7.0  #6A579A
# 17           uniform  7.0  #3B7185
# 18           uniform  5.0  #E0785F
# 19           uniform  6.0  #35474E
# 20          gaussian  6.0  #154F8D
# 21           uniform  6.0  #8DC2DC
# 22          gaussian  6.0  #409BBE
# 23           uniform  6.0  #76C1C3
# 24           uniform  6.0  #CD4F45
# 25          gaussian  6.0  #9FD6BD
# 26           uniform  NaN  #B3D566
# 27           uniform  NaN  #D5C888
# 28               NaN  NaN      NaN
# 29               NaN  NaN      NaN
# 30               NaN  NaN      NaN
# 31               NaN  NaN      NaN
# 32               NaN  NaN      NaN
# 33               NaN  NaN      NaN
# 34               NaN  NaN      NaN
# 35               NaN  NaN      NaN
# 36               NaN  NaN      NaN

# %%
plt.figure(figsize=(6, 6))
m = ipmag.make_orthographic_map(central_longitude=180, central_latitude=0)

viridis = cm = plt.get_cmap('viridis') 
cNorm  = matplotlib.colors.Normalize(vmin=720, vmax=1270)
scalarMap = matplotlib.cm.ScalarMappable(norm=cNorm, cmap='viridis_r')
# scalarMap = matplotlib.cm.ScalarMappable(norm=cNorm, cmap='Spectral_r')

for n in poles.index:
    rgba = scalarMap.to_rgba(poles.AgeNominal[n])
    hex_color = colors.rgb2hex(rgba)
    hex_color
    ipmag.plot_pole(m,poles.PLon[n],poles.PLat[n],poles.A95[n],color=hex_color)
scalarMap.set_array(np.linspace(720,1110))    
plt.colorbar(scalarMap,orientation='horizontal',fraction=0.046, pad=0.04)
plt.title('Laurentia polar wander')
# plt.savefig('../figure/Logan_Kewee_Grenville_Loop.pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6, 6))
m = ipmag.make_orthographic_map(central_longitude=330, central_latitude=0)

viridis = cm = plt.get_cmap('viridis') 
cNorm  = matplotlib.colors.Normalize(vmin=720, vmax=1270)
scalarMap = matplotlib.cm.ScalarMappable(norm=cNorm, cmap='viridis_r')
# scalarMap = matplotlib.cm.ScalarMappable(norm=cNorm, cmap='Spectral_r')

for n in poles.index:
    rgba = scalarMap.to_rgba(poles.AgeNominal[n])
    hex_color = colors.rgb2hex(rgba)
    hex_color
    ipmag.plot_pole(m,poles.PLon[n]-180,-poles.PLat[n],poles.A95[n],color=hex_color)
ipmag.plot_pole(m, 338.6, -10.3, 5.2, marker = 'd', color = 'r', label = 'Halls P pole')
ipmag.plot_pole(m, 338.6, -10.3, 5.2, marker = 'd', color = 'r', label = 'Halls P pole')
ipmag.plot_pole(m, 338.6, -10.3, 5.2, marker = 'd', color = 'r', label = 'Halls P pole')



scalarMap.set_array(np.linspace(720,1110))    
plt.colorbar(scalarMap,orientation='horizontal',fraction=0.046, pad=0.04)
plt.title('Laurentia polar wander "reversed"')
# plt.savefig('../figure/Logan_Kewee_Grenville_Loop_rev.pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6, 6))
m = ipmag.make_orthographic_map(central_longitude=180, central_latitude=0)

viridis = cm = plt.get_cmap('viridis') 
cNorm  = matplotlib.colors.Normalize(vmin=720, vmax=1270)
scalarMap = matplotlib.cm.ScalarMappable(norm=cNorm, cmap='viridis_r')
# scalarMap = matplotlib.cm.ScalarMappable(norm=cNorm, cmap='Spectral_r')

for n in poles.index:
    rgba = scalarMap.to_rgba(poles.AgeNominal[n])
    hex_color = colors.rgb2hex(rgba)
    hex_color
    ipmag.plot_pole(m,poles.PLon[n],poles.PLat[n],poles.A95[n],color=hex_color)
scalarMap.set_array(np.linspace(720,1110))    

ipmag.plot_pole(m, 142.5, -36, 6, marker = 'o', color = 'r', label = 'Haliburton A pole')
ipmag.plot_pole(m, 172.3, 24.5, 16, marker = 's', color = 'r', label = 'Haliburton B pole')
ipmag.plot_pole(m, 167, -3, 7, marker = 'd', color = 'r', label = 'Haliburton C pole')

ipmag.plot_pole(m, 180-338.6, 10.3, 5.2, marker = 'd', color = 'r', label = 'Halls P pole')
ipmag.plot_pole(m, 180-345.5, -5.1, 5.2, marker = 'd', color = 'g', label = 'Halls B pole')
ipmag.plot_pole(m, 180-348.5, 17.4, 5.2, marker = 'd', color = 'b', label = 'Halls C pole')


plt.colorbar(scalarMap,orientation='horizontal',fraction=0.046, pad=0.04)
plt.title('Laurentia polar wander')
plt.legend()
# plt.savefig('../figure/Buchan1978_components.pdf', bbox_inches='tight')
plt.show()
