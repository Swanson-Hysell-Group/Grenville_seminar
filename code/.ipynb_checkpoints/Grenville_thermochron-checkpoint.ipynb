# %% [markdown]
# # Notebook for analyzing Grenville thermochron data compilation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ## Load in compilation file

# %%
study_summary = pd.read_csv('../data/thermochron_compilation/study_summary.csv')
study_summary = study_summary[study_summary['Age'] < 1090]
study_summary = study_summary.sort_values(by='Age').reset_index(drop=1)

study_summary.head()
# Out:
#     Sample_No    Age  Error_Plus  Error_Minus Age_Method  \
# 0      C-93-9  599.0        16.0         16.0       U/Pb
# 1   FA-810101  630.0        64.0         64.0       K/Ar
# 2  FA-810101A  654.0        46.0         46.0       K/Ar
# 3     SSA-10A  731.0         8.0          8.0      Ar/Ar
# 4     SSA-11B  758.0         8.0          8.0      Ar/Ar
#
#         Age_Interpretation                                           Age_Note  \
# 0                    Reset                                            granite
# 1  Igneous Crystallization  medium- to fine-grained massive dark grey diab...
# 2  Igneous Crystallization  fine- to medium-grained massive dark grey diab...
# 3                  Cooling                                          pegmatite
# 4                  Cooling                                        amphibolite
#
#      Age_Material      Age_Technique Age_Qualifier Geological_Province  \
# 0  Zircon, Rutile               TIMS        Direct  Grenville Province
# 1      Whole Rock  Ar Furnace-Fusion      Estimate  Grenville Province
# 2      Whole Rock  Ar Furnace-Fusion      Estimate  Grenville Province
# 3      K-Feldspar    Ar Furnace-Step      Estimate  Grenville Province
# 4      K-Feldspar  Ar Furnace-Fusion      Estimate  Grenville Province
#
#   Province  Latitude  Longitude  \
# 0       ON  44.91704  -77.10352
# 1       QC  47.23340  -78.78313
# 2       QC  47.23340  -78.78313
# 3       ON  45.50006  -78.24977
# 4       ON  45.58339  -78.38311
#
#                                             Location  \
# 0                                          Sand Lake
# 1  3 km NW of the rapids below Lc des Cinq Milles...
# 2  3 km NW of the rapids below Lac des Cinq Mille...
# 3  Approx. 50 km WSE of Pembroke. Location approx...
# 4             Huntsville area. Location approximate.
#
#                          Geological_Info    Rock_Type  \
# 0  Mazinaw terrane - Norway Lake granite     Plutonic
# 1       Parauthochthonous Belt - unknown     Plutonic
# 2       Parauthochthonous Belt - unknown     Plutonic
# 3          Central Gneiss Belt - unknown     Plutonic
# 4          Central Gneiss Belt - unknown  Metamorphic
#
#                                     Rock_Description  \
# 0                                            granite
# 1  medium- to fine-grained massive dark grey diab...
# 2  fine- to medium-grained massive dark grey diab...
# 3                                          pegmatite
# 4                                        amphibolite
#
#                                           References
# 0  Corfu, F. and Easton, R.M., 1995. U-Pb geochro...
# 1  Stevens, R.D., Delabio, R.N. and Lachance, G.R...
# 2  Stevens, R.D., Delabio, R.N. and Lachance, G.R...
# 3  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 4  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...

# %%
study_summary.Age_Material.unique()
# Out:
# array(['Zircon, Rutile', 'Whole Rock', 'K-Feldspar', 'Biotite',
#        'Titanite', 'Zircon, Monazite', 'Muscovite', 'Rutile',
#        'Phlogopite', 'Hornblende', 'Zircon', 'Zircon, Titanite',
#        'Monazite', 'Uraninite', 'Monazite, Xenotime', 'Garnet',
#        'Monazite, Titanite', 'Thorianite, Uraninite', 'Thorianite'],
#       dtype=object)

# %% [markdown]
# ### plot all ages

# %%
plt.figure(figsize=(15, 15))
for i in range(len(study_summary.Age_Material.unique())):
    this_material = study_summary[study_summary['Age_Material'] == study_summary.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index, 0, this_material['Error_Plus'], 
                 color='C'+str(i), ls='None', label=study_summary.Age_Material.unique()[i])
plt.legend()

# %% [markdown]
# ### plot all rutile ages

# %%
plt.figure(figsize=(8, 6))

rutile_data = study_summary[study_summary['Age_Material'] == 'Rutile'].reset_index(drop=1)
plt.errorbar(rutile_data['Age'], rutile_data.index, 0, rutile_data['Error_Plus'], 
                 color='C0', ls='None', label='rutile')
# plt.legend()
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Let's use general constraints on the closure temperatures for the minerals.
#
# - Biotite: 280 +- 40
# - Hornblende: 530 +- 50
# - Monazite: 600-650
# - Titanite: 660-700
# - Rutile: 500-540

# %%
closure_temp_bounds_dict = {'Biotite':[280, 60], 
                            'Muscovite':[350, 50],
                            'Hornblende':[500, 80], 
                            'Rutile':[625, 125], 
                            'Monazite':[1000,100], 
                            'Titanite':[575, 75],
                            'Zircon': [950, 50],
                            'K-Feldspar':[250, 50] }

color_dict = {'Biotite':'C0', 
              'Muscovite':'C1',
              'Hornblende':'C2', 
              'Rutile':'C3', 
              'Monazite':'C4', 
              'Titanite':'C5', 
              'Zircon':'C6', 
              'K-Feldspar': 'C7',
             'Whole Rock': 'k'}

# %% [markdown]
# ## Get Bancroft Terrane records
#
# - Berger 1981 Ar
# - Cosca 1991 Ar
# - Mezger U/Pb titanite

# %%
Bancroft_records = study_summary[study_summary['Geological_Info'].str.contains('Bancroft')]
Bancroft_records = Bancroft_records[~Bancroft_records['Age_Material'].str.contains('Allanite|Garnet|Zircon|Phlogopite')]
Bancroft_records.head()
# Out:
#    Sample_No    Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 26   94GG01b  891.0         7.0          7.0      Ar/Ar            Cooling
# 41    B2-149  898.0         7.1          7.1      Ar/Ar            Cooling
# 48   94GG01a  901.0         7.0          7.0      Ar/Ar            Cooling
# 58     G4-22  905.0         6.1          6.1      Ar/Ar            Cooling
# 71    D1-190  909.0         7.0          7.0      Ar/Ar            Cooling
#
#    Age_Note Age_Material    Age_Technique Age_Qualifier Geological_Province  \
# 26      NaN      Biotite  Ar Furnace-Step        Direct  Grenville Province
# 41      NaN      Biotite  Ar Furnace-Step        Direct  Grenville Province
# 48      NaN      Biotite  Ar Furnace-Step        Direct  Grenville Province
# 58      NaN      Biotite  Ar Furnace-Step        Direct  Grenville Province
# 71      NaN      Biotite  Ar Furnace-Step        Direct  Grenville Province
#
#    Province  Latitude  Longitude                      Location  \
# 26       ON       NaN        NaN  Central Metasedimentary Belt
# 41       ON       NaN        NaN  Central Metasedimentary Belt
# 48       ON       NaN        NaN  Central Metasedimentary Belt
# 58       ON       NaN        NaN  Central Metasedimentary Belt
# 71       ON       NaN        NaN  Central Metasedimentary Belt
#
#                                    Geological_Info    Rock_Type  \
# 26  Central Metasedimentary Belt, Bancroft Terrane  Metamorphic
# 41  Central Metasedimentary Belt, Bancroft Terrane  Metamorphic
# 48  Central Metasedimentary Belt, Bancroft Terrane  Metamorphic
# 58  Central Metasedimentary Belt, Bancroft Terrane  Metamorphic
# 71  Central Metasedimentary Belt, Bancroft Terrane  Metamorphic
#
#    Rock_Description                                         References
# 26              NaN  Warnock, A. C., Kodama, K. P., & Zeitler, P. K...
# 41              NaN  Berger, G. W., & York, D. (1981). Geothermomet...
# 48              NaN  Warnock, A. C., Kodama, K. P., & Zeitler, P. K...
# 58              NaN  Berger, G. W., & York, D. (1981). Geothermomet...
# 71              NaN  Berger, G. W., & York, D. (1981). Geothermomet...

# %%
plt.figure(figsize=(10, 10))
for i in range(len(Bancroft_records.Age_Material.unique())):
    this_material = Bancroft_records[Bancroft_records['Age_Material'] == Bancroft_records.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index, 0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Bancroft_records.Age_Material.unique()[i]], ls='None', label=Bancroft_records.Age_Material.unique()[i])
plt.title('Bancroft Terrane thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 8))
for i in Bancroft_records.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Bancroft_records[Bancroft_records['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.ylim(0, 1200)
plt.legend()
plt.show()

# %% [markdown]
# ## Get Elzevir Terrane records

# %%
Elzevir_records = study_summary[study_summary['Geological_Info'].str.contains('Elzevir|Elsevier')]
Elzevir_records = Elzevir_records[~Elzevir_records['Age_Material'].str.contains('Allanite|Garnet|Zircon|K-Feldspar|Phlogopite')]
Elzevir_records.head()
# Out:
#    Sample_No    Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 15    HL86-3  850.0        20.0         20.0      Ar/Ar            Cooling
# 33   HL86-2B  895.0         4.0          4.0      Ar/Ar            Cooling
# 38   HL86-2B  897.0         4.0          4.0      Ar/Ar            Cooling
# 51    HL86-5  903.0         6.0          6.0      Ar/Ar            Cooling
# 85   HL86-2C  917.0         4.0          4.0      Ar/Ar            Cooling
#
#        Age_Note Age_Material      Age_Technique Age_Qualifier  \
# 15  amphibolite      Biotite  Ar Furnace-Fusion      Estimate
# 33       gneiss    Muscovite    Ar Furnace-Step        Direct
# 38       gneiss      Biotite  Ar Furnace-Fusion      Estimate
# 51       schist    Muscovite    Ar Furnace-Step        Direct
# 85       gneiss      Biotite  Ar Furnace-Fusion      Estimate
#
#    Geological_Province Province  Latitude  Longitude  \
# 15  Grenville Province       ON  44.61256  -77.16640
# 33  Grenville Province       ON  44.64589  -77.09972
# 38  Grenville Province       ON  44.64589  -77.09972
# 51  Grenville Province       ON  44.54173  -77.31640
# 85  Grenville Province       ON  44.64589  -77.09972
#
#                              Location  \
# 15  NE of Madoc. Location approximate
# 33  NE of Madoc. Location approximate
# 38  NE of Madoc. Location approximate
# 51               Location approximate
# 85  NE of Madoc. Location approximate
#
#                                       Geological_Info    Rock_Type  \
# 15  Central Metasedimentary Belt, Elzevir terrane ...  Metamorphic
# 33  Central Metasedimentary Belt, Elzevir terrane ...  Metamorphic
# 38  Central Metasedimentary Belt, Elzevir terrane ...  Metamorphic
# 51  Central Metasedimentary Belt, Elzevir terrane ...  Metamorphic
# 85  Central Metasedimentary Belt, Elzevir terrane ...  Metamorphic
#
#    Rock_Description                                         References
# 15      amphibolite  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 33           gneiss  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 38           gneiss  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 51           schist  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 85           gneiss  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...

# %%
plt.figure(figsize=(10, 10))
for i in range(len(Elzevir_records.Age_Material.unique())):
    this_material = Elzevir_records[Elzevir_records['Age_Material'] == Elzevir_records.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index, 0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Elzevir_records.Age_Material.unique()[i]], ls='None', label=Elzevir_records.Age_Material.unique()[i])
plt.title('Elzevir Terrane thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 8))
for i in Elzevir_records.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Elzevir_records[Elzevir_records['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.ylim(0, 1200)
plt.legend()
plt.show()

# %% [markdown]
# ## Get Mazinaw Terrane records

# %%
Mazinaw_records = study_summary[study_summary['Geological_Info'].str.contains('Mazinaw')]
Mazinaw_records = Mazinaw_records[~Mazinaw_records['Age_Material'].str.contains('Allanite|Garnet|Zircon|K-Feldspar|Phlogopite')]
Mazinaw_records.head()
# Out:
#       Sample_No    Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 77   C-93-2 KF2  915.0        18.0         18.0      Pb/Pb        Metamorphic
# 90   C-93-2 KF2  923.0        12.0         12.0      Pb/Pb        Metamorphic
# 97       HL86-1  925.0         6.0          6.0      Ar/Ar            Cooling
# 133      JOL164  944.0         4.0          4.0      Ar/Ar            Cooling
# 144   C-93-3 HS  950.0        13.0         13.0      Pb/Pb        Metamorphic
#
#                                               Age_Note Age_Material  \
# 77   matrix-poor monolithic metavolcanic breccia, m...       Rutile
# 90   matrix-poor monolithic metavolcanic breccia, m...       Rutile
# 97                                         amphibolite   Hornblende
# 133                                        amphibolite   Hornblende
# 144                 trondhjemite, cuts marbles in area       Rutile
#
#        Age_Technique Age_Qualifier Geological_Province Province  Latitude  \
# 77              TIMS        Direct  Grenville Province       ON  44.81030
# 90              TIMS        Direct  Grenville Province       ON  44.81030
# 97   Ar Furnace-Step        Direct  Grenville Province       ON  44.69173
# 133       Laser-Step        Direct  Grenville Province       ON  45.17885
# 144             TIMS      Estimate  Grenville Province       ON  44.83140
#
#      Longitude                              Location  \
# 77   -77.10974                      Kashwakamak Lake
# 90   -77.10974                      Kashwakamak Lake
# 97   -76.99972  NE of Kingston. Location approximate
# 133  -76.64979             Robertson Lake Shear Zone
# 144  -77.10460                          Mitchell Bay
#
#                                        Geological_Info    Rock_Type  \
# 77             Mazinaw terrane - Kashwakamak Formation     Volcanic
# 90             Mazinaw terrane - Kashwakamak Formation     Volcanic
# 97   Central Metasedimentary Belt, Frontenac terran...  Metamorphic
# 133                          Mazinaw terrane - unknown  Metamorphic
# 144                     Mazinaw terrane - Helena stock     Plutonic
#
#                                       Rock_Description  \
# 77   matrix-poor monolithic metavolcanic breccia, m...
# 90   matrix-poor monolithic metavolcanic breccia, m...
# 97                                         amphibolite
# 133                                        amphibolite
# 144                 trondhjemite, cuts marbles in area
#
#                                             References
# 77   Corfu, F. and Easton, R.M., 1995. U-Pb geochro...
# 90   Corfu, F. and Easton, R.M., 1995. U-Pb geochro...
# 97   Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 133  Busch, J.P., van der Pljuim, B.A., Hall, C.M. ...
# 144  Corfu, F. and Easton, R.M., 1995. U-Pb geochro...

# %%
plt.figure(figsize=(10, 10))
for i in range(len(Mazinaw_records.Age_Material.unique())):
    this_material = Mazinaw_records[Mazinaw_records['Age_Material'] == Mazinaw_records.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index, 0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Mazinaw_records.Age_Material.unique()[i]], ls='None', label=Mazinaw_records.Age_Material.unique()[i])
plt.title('Mazinaw Terrane thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 8))
for i in Mazinaw_records.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Mazinaw_records[Mazinaw_records['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.ylim(0, 1200)
plt.legend()
plt.show()

# %% [markdown]
# ## Get Sharbot Lake/Frontenac Terrane records

# %%
Sharbot_Frontenac_records = study_summary[study_summary['Geological_Info'].str.contains('Sharbot|Frontenac')]
Sharbot_Frontenac_records = Sharbot_Frontenac_records[~Sharbot_Frontenac_records['Age_Material'].str.contains('Allanite|Garnet|Zircon|K-Feldspar|Phlogopite|Thorianite|Uranianite')]
Sharbot_Frontenac_records.head()
# Out:
#     Sample_No     Age  Error_Plus  Error_Minus Age_Method  \
# 10      JMV-1   821.0         0.0          0.0       U/Pb
# 28     SRD104   893.0         2.0          2.0      Ar/Ar
# 97     HL86-1   925.0         6.0          6.0      Ar/Ar
# 175   FA86E-6   967.0         6.0          6.0      Ar/Ar
# 315   FA86-10  1013.0         6.0          6.0      Ar/Ar
#
#           Age_Interpretation            Age_Note Age_Material  \
# 10   Igneous Crystallization                 Ore     Titanite
# 28                   Cooling  pegmatite mylonite    Muscovite
# 97                   Cooling         amphibolite   Hornblende
# 175                  Cooling         amphibolite      Biotite
# 315                  Cooling         amphibolite   Hornblende
#
#          Age_Technique Age_Qualifier Geological_Province Province  Latitude  \
# 10                TIMS     Uncertain  Grenville Province       QC  46.58338
# 28          Laser-Step        Direct  Grenville Province       ON  44.94568
# 97     Ar Furnace-Step        Direct  Grenville Province       ON  44.69173
# 175  Ar Furnace-Fusion      Estimate  Grenville Province       ON  44.44589
# 315    Ar Furnace-Step        Direct  Grenville Province       ON  44.76673
#
#      Longitude                                           Location  \
# 10   -75.49965        N of Mont Laurier. Coordinates approximate.
# 28   -76.67643                          Robertson Lake Shear Zone
# 97   -76.99972               NE of Kingston. Location approximate
# 175  -76.68304                               Location approximate
# 315  -76.77471  Midway between Ottawa and Kingston. Location a...
#
#                                        Geological_Info     Rock_Type  \
# 10   Frontenac - Adirondack Lowlands terrane - unknown  Hydrothermal
# 28     Sharbot Lake Domain - Robertson Lake Shear Zone      Plutonic
# 97   Central Metasedimentary Belt, Frontenac terran...   Metamorphic
# 175  Central Metasedimentary Belt, Frontenac terran...   Metamorphic
# 315  Central Metasedimentary Belt, Frontenac terran...   Metamorphic
#
#        Rock_Description                                         References
# 10                  Ore  Rimsaite, J., 1985. Petrography, petrochemistr...
# 28   pegmatite mylonite  Busch, J.P., van der Pljuim, B.A., Hall, C.M. ...
# 97          amphibolite  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 175         amphibolite  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 315         amphibolite  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...

# %%
plt.figure(figsize=(10, 10))
for i in range(len(Sharbot_Frontenac_records.Age_Material.unique())):
    this_material = Sharbot_Frontenac_records[Sharbot_Frontenac_records['Age_Material'] == Sharbot_Frontenac_records.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index, 0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Sharbot_Frontenac_records.Age_Material.unique()[i]], ls='None', label=Sharbot_Frontenac_records.Age_Material.unique()[i])
plt.title('Sharbot Lake/Frontenac Terrane thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 8))
for i in Sharbot_records.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Sharbot_records[Sharbot_records['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.ylim(0, 1200)
plt.legend()
plt.show()

# %% [markdown]
# ## Load Adirondack lowlands ages

# %%
Adirondack_lowlands_ages = pd.read_csv('../data/thermochron_compilation/Adirondack_lowlands.csv')
Adirondack_lowlands_ages = Adirondack_lowlands_ages[Adirondack_lowlands_ages['Age'] < 1090]
Adirondack_lowlands_ages = Adirondack_lowlands_ages[Adirondack_lowlands_ages['Age_Material'] != 'Garnet']
Adirondack_lowlands_ages = Adirondack_lowlands_ages.sort_values(by=['Age_Material', 'Age']).reset_index(drop=1)
Adirondack_lowlands_ages.head()
# Out:
#   Sample_No    Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 0  SE596-49  895.0         1.0          1.0      Ar/Ar            Cooling
# 1  AL97-12a  896.0         3.0          3.0      Ar/Ar            Cooling
# 2   AL97-31  898.0         3.0          3.0      Ar/Ar            Cooling
# 3  PP596-60  899.0         1.0          1.0      Ar/Ar            Cooling
# 4   AL98-43  901.0         3.0          3.0      Ar/Ar            Cooling
#
#       Age_Note Age_Material Age_Technique Age_Qualifier Geological_Province  \
# 0  Plateau Age      Biotite    Laser-Step        Direct  Grenville Province
# 1          NaN      Biotite    Laser-Step           NaN  Grenville Province
# 2          NaN      Biotite    Laser-Step           NaN  Grenville Province
# 3  Plateau Age      Biotite    Laser-Step        Direct  Grenville Province
# 4          NaN      Biotite    Laser-Step           NaN  Grenville Province
#
#   Province  Latitude  Longitude  \
# 0       NY  44.39000  -75.19000
# 1       NY  44.44443  -75.18825
# 2       NY  44.19778  -75.28213
# 3       NY  44.53000  -75.04000
# 4       NY  44.34945  -75.27223
#
#                                             Location  \
# 0  On Rt 87, north of Dana Hill Rd. 1.9 miles sou...
# 1                                Adirondack Lowlands
# 2                                Adirondack Lowlands
# 3  1 mile southwest of Pierrepont on Rt. 2. Outcr...
# 4                                Adirondack Lowlands
#
#               Geological_Info    Rock_Type                  Rock_Description  \
# 0  Carthage-Colton shear zone  Metamorphic                       amphibolite
# 1         Adirondack Lowlands  Metamorphic                Popple Hill gneiss
# 2         Adirondack Lowlands     Plutonic                    Hermon granite
# 3  Carthage-Colton shear zone  Metamorphic  garnet biotite sillmanite schist
# 4         Adirondack Lowlands     Plutonic                    Hermon granite
#
#                                           References
# 0  Streepey, M.M., van der Pluijm, B.A., Essene, ...
# 1  Dahl, P.S., Pomfrey, M.E., and Foland, K.A., 2...
# 2  Dahl, P.S., Pomfrey, M.E., and Foland, K.A., 2...
# 3  Streepey, M.M., van der Pluijm, B.A., Essene, ...
# 4  Dahl, P.S., Pomfrey, M.E., and Foland, K.A., 2...

# %%
Adirondack_lowlands_ages.Age_Material.unique()
# Out:
# array(['Biotite', 'Hornblende', 'Rutile', 'Titanite'], dtype=object)

# %%
plt.figure(figsize=(15, 15))
for i in range(len(Adirondack_lowlands_ages.Age_Material.unique())):
    this_material = Adirondack_lowlands_ages[Adirondack_lowlands_ages['Age_Material'] == Adirondack_lowlands_ages.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index, 0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Adirondack_lowlands_ages.Age_Material.unique()[i]], ls='None', label=Adirondack_lowlands_ages.Age_Material.unique()[i])
plt.title('Adirondack Lowlands thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()

# %%
plt.figure(figsize=(15, 8))
for i in Adirondack_lowlands_ages.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Adirondack_lowlands_ages[Adirondack_lowlands_ages['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %% [markdown]
# ## Load Adirondack highlands ages

# %%
Adirondack_highlands_ages = pd.read_csv('../data/thermochron_compilation/Adirondack_highlands.csv')
Adirondack_highlands_ages = Adirondack_highlands_ages[Adirondack_highlands_ages['Age'] < 1090]
Adirondack_highlands_ages = Adirondack_highlands_ages[Adirondack_highlands_ages['Age_Material'] != 'Garnet']
Adirondack_highlands_ages = Adirondack_highlands_ages.sort_values(by=['Age_Material', 'Age']).reset_index(drop=1)
Adirondack_highlands_ages.head()
# Out:
#   Sample_No     Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 0      A142  919.00        1.00         1.00      Ar/Ar            Cooling
# 1  CN596-56  924.00        2.00         2.00      Ar/Ar            Cooling
# 2      A136  937.00        8.00         8.00      Ar/Ar            Cooling
# 3      A136  943.30        1.37         1.37      Ar/Ar            Cooling
# 4      A145  947.27        1.12         1.12      Ar/Ar            Cooling
#
#         Age_Note Age_Material Age_Technique  Age_Qualifier  \
# 0  Total Gas Age      Biotite    Laser-Step       Estimate
# 1    Plateau Age      Biotite    Laser-Step         Direct
# 2  Total Gas Age      Biotite    Laser-Step       Estimate
# 3    Plateau Age   Hornblende    Laser-Step  Total Gas Age
# 4    Plateau Age   Hornblende    Laser-Step  Total Gas Age
#
#   Geological_Province Province  Latitude  Longitude  \
# 0  Grenville Province       NY     44.17     -75.16
# 1  Grenville Province       NY     44.51     -74.99
# 2  Grenville Province       NY     44.56     -74.80
# 3  Grenville Province       NY     44.56     -74.80
# 4  Grenville Province       NY     44.00     -75.43
#
#                                             Location  \
# 0  Small outcrop on the east side of Mud Lake Rd ...
# 1  0.2 miles south of junction of Hanson Rd and O...
# 2  Small outcrop on Joe Indian Rd at the crest of...
# 3  Small outcrop on Joe Indian Rd. at the crest o...
# 4  About 2 mi. E of Texas on Texas Rd., 6 mi. fro...
#
#               Geological_Info    Rock_Type    Rock_Description  \
# 0  Carthage-Colton shear zone  Metamorphic  hornblende granite
# 1  Carthage-Colton shear zone  Metamorphic  hornblende granite
# 2  Carthage-Colton shear zone  Metamorphic  hornblende granite
# 3        Adirondack Highlands  Metamorphic                 NaN
# 4        Adirondack Highlands  Metamorphic                 NaN
#
#                                           References
# 0  Streepey, M.M., van der Pluijm, B.A., Essene, ...
# 1  Streepey, M.M., van der Pluijm, B.A., Essene, ...
# 2  Streepey, M.M., van der Pluijm, B.A., Essene, ...
# 3  Streepey, M.M., Lithgow-Bertelloni, C., van de...
# 4  Streepey, M.M., Lithgow-Bertelloni, C., van de...

# %%
Adirondack_highlands_ages.Age_Material.unique()
# Out:
# array(['Biotite', 'Hornblende', 'Monazite', 'Rutile', 'Titanite'],
#       dtype=object)

# %%
plt.figure(figsize=(15, 15))
for i in range(len(Adirondack_highlands_ages.Age_Material.unique())):
    this_material = Adirondack_highlands_ages[Adirondack_highlands_ages['Age_Material'] == Adirondack_highlands_ages.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index,  0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Adirondack_highlands_ages.Age_Material.unique()[i]], ls='None', label=Adirondack_highlands_ages.Age_Material.unique()[i])
plt.title('Adirondack Highlands thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()

# %%
plt.figure(figsize=(15, 8))
for i in Adirondack_highlands_ages.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Adirondack_highlands_ages[Adirondack_highlands_ages['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %% [markdown]
# ## Load Central Gneiss Belt ages

# %%
Central_Gneiss_Belt_ages = pd.read_csv('../data/thermochron_compilation/Central_Gneiss_Belt.csv')
Central_Gneiss_Belt_ages = Central_Gneiss_Belt_ages[Central_Gneiss_Belt_ages['Age'] < 1090]
Central_Gneiss_Belt_ages = Central_Gneiss_Belt_ages[~Central_Gneiss_Belt_ages['Age_Material'].str.contains('Muscovite|Allanite|Garnet|Zircon|K-Feldspar')]
Central_Gneiss_Belt_ages = Central_Gneiss_Belt_ages.sort_values(by=['Age_Material', 'Age']).reset_index(drop=1)
Central_Gneiss_Belt_ages.head()
# Out:
#   Sample_No    Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 0    SSA-12  875.0         8.0          8.0      Ar/Ar            Cooling
# 1   SSA-10B  904.0         8.0          8.0      Ar/Ar            Cooling
# 2     PSA-2  904.0         8.0          8.0      Ar/Ar            Cooling
# 3    SSA-8A  907.0         8.0          8.0      Ar/Ar            Cooling
# 4     RDT-3  924.0         8.0          8.0      Ar/Ar            Cooling
#
#       Age_Note Age_Material      Age_Technique Age_Qualifier  \
# 0       gneiss      Biotite    Ar Furnace-Step        Direct
# 1  amphibolite      Biotite  Ar Furnace-Fusion        Direct
# 2       gneiss      Biotite    Ar Furnace-Step        Direct
# 3       gneiss      Biotite    Ar Furnace-Step        Direct
# 4       gneiss      Biotite    Ar Furnace-Step        Direct
#
#   Geological_Province Province  Latitude  Longitude  \
# 0  Grenville Province       ON  45.58720  -78.50004
# 1  Grenville Province       ON  45.50006  -78.24977
# 2  Grenville Province       ON  45.44172  -80.02066
# 3  Grenville Province       ON  45.35005  -79.13314
# 4  Grenville Province       ON  45.24958  -78.94818
#
#                                             Location  \
# 0  No topographic reference given in report; loca...
# 1  Approx. 50 km WSE of Pembroke. Location approx...
# 2  Location very approximate; not specifically lo...
# 3            NE of Huntsville. Location approximate.
# 4  No topographic reference given in report; loca...
#
#                                      Geological_Info    Rock_Type  \
# 0  Central Metasedimentary Belt, Algonquin/McClin...  Metamorphic
# 1                      Central Gneiss Belt - unknown  Metamorphic
# 2                      Central Gneiss Belt - unknown  Metamorphic
# 3    Central Gneiss Belt, Algonquin Domain - unknown  Metamorphic
# 4      Central Gneiss Belt, Muskoka Domain - unknown  Metamorphic
#
#   Rock_Description                                         References
# 0           gneiss  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 1      amphibolite  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 2           gneiss  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 3           gneiss  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 4           gneiss  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...

# %%
Central_Gneiss_Belt_ages.Age_Material.unique()
# Out:
# array(['Biotite', 'Hornblende', 'Monazite', 'Rutile', 'Titanite'],
#       dtype=object)

# %%
plt.figure(figsize=(15, 15))
for i in range(len(Central_Gneiss_Belt_ages.Age_Material.unique())):
    this_material = Central_Gneiss_Belt_ages[Central_Gneiss_Belt_ages['Age_Material'] == Central_Gneiss_Belt_ages.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index,  0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Central_Gneiss_Belt_ages.Age_Material.unique()[i]], ls='None', label=Central_Gneiss_Belt_ages.Age_Material.unique()[i])
plt.title('Central Gneiss Belt thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()

# %%
plt.figure(figsize=(15, 8))
for i in Central_Gneiss_Belt_ages.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Central_Gneiss_Belt_ages[Central_Gneiss_Belt_ages['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %% [markdown]
# ### Whitestone diorite Ar Hornblende and Biotite thermochron

# %%
Whitestone_ages = pd.read_csv('../data/thermochron_compilation/Dallmeyer1980a.csv')
Whitestone_ages = Whitestone_ages.sort_values(by=['Age_Material', 'Age']).reset_index(drop=1)
Whitestone_ages.head()
# Out:
#   Sample_No  Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 0     WA-15  936          15           15      Ar/Ar            Cooling
# 1     WA-21  960          15           15      Ar/Ar            Cooling
# 2     WA-15  965          15           15      Ar/Ar            Cooling
# 3     WA-21  991          15           15      Ar/Ar            Cooling
#
#    Age_Note Age_Material    Age_Technique Age_Qualifier Geological_Province  \
# 0       NaN      Biotite  Ar Furnace-Step        Direct  Grenville Province
# 1       NaN      Biotite  Ar Furnace-Step        Direct  Grenville Province
# 2       NaN   Hornblende  Ar Furnace-Step        Direct  Grenville Province
# 3       NaN   Hornblende  Ar Furnace-Step        Direct  Grenville Province
#
#   Province  Latitude  Longitude            Location  Geological_Info  \
# 0       ON       NaN        NaN  Whitestone diorite              NaN
# 1       ON       NaN        NaN  Whitestone diorite              NaN
# 2       ON       NaN        NaN  Whitestone diorite              NaN
# 3       ON       NaN        NaN  Whitestone diorite              NaN
#
#   Rock_Type Rock_Description  \
# 0  Plutonic          diorite
# 1  Plutonic          diorite
# 2  Plutonic          diorite
# 3  Plutonic          diorite
#
#                                           References
# 0  Dallmeyer, R. D., & Sutter, J. F. (1980). Acqu...
# 1  Dallmeyer, R. D., & Sutter, J. F. (1980). Acqu...
# 2  Dallmeyer, R. D., & Sutter, J. F. (1980). Acqu...
# 3  Dallmeyer, R. D., & Sutter, J. F. (1980). Acqu...

# %%
plt.figure(figsize=(10, 10))
for i in range(len(Whitestone_ages.Age_Material.unique())):
    this_material = Whitestone_ages[Whitestone_ages['Age_Material'] == Whitestone_ages.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index,  0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Whitestone_ages.Age_Material.unique()[i]], ls='None', label=Whitestone_ages.Age_Material.unique()[i])
plt.title('Whitestone thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()

# %%
plt.figure(figsize=(15, 8))
for i in Whitestone_ages.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Whitestone_ages[Whitestone_ages['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
plt.ylim(0, 1200)
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %% [markdown]
# ## Load Central Metasedimentary Belt ages

# %%
Central_Meta_Belt_ages = pd.read_csv('../data/thermochron_compilation/Central_Metasedimentary_Belt.csv')
Central_Meta_Belt_ages = Central_Meta_Belt_ages[Central_Meta_Belt_ages['Age'] < 1090]
Central_Meta_Belt_ages = Central_Meta_Belt_ages[~Central_Meta_Belt_ages['Age_Material'].str.contains(
    'Muscovite|Allanite|Garnet|Zircon|K-Feldspar|Whole Rock|Phlogopite|Thorianite|Uraninite')]
Central_Meta_Belt_ages = Central_Meta_Belt_ages.sort_values(by=['Age_Material', 'Age']).reset_index(drop=1)
Central_Meta_Belt_ages.head()
# Out:
#   Sample_No  Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 0  MIN86-3A  848         6.0          6.0      Ar/Ar            Cooling
# 1    HL86-3  850        20.0         20.0      Ar/Ar            Cooling
# 2   HL86-2B  897         4.0          4.0      Ar/Ar            Cooling
# 3    LVT130  905         2.0          2.0      Ar/Ar            Cooling
# 4   HL86-2C  917         4.0          4.0      Ar/Ar            Cooling
#
#                                             Age_Note Age_Material  \
# 0                                        amphibolite      Biotite
# 1                                        amphibolite      Biotite
# 2                                             gneiss      Biotite
# 3  biotite muscovite quartz plagioclase sillimani...      Biotite
# 4                                             gneiss      Biotite
#
#        Age_Technique Age_Qualifier Geological_Province Province  Latitude  \
# 0  Ar Furnace-Fusion      Estimate  Grenville Province       ON  45.03339
# 1  Ar Furnace-Fusion      Estimate  Grenville Province       ON  44.61256
# 2  Ar Furnace-Fusion      Estimate  Grenville Province       ON  44.64589
# 3         Laser-Step        Direct  Grenville Province      NaN  45.05876
# 4  Ar Furnace-Fusion      Estimate  Grenville Province       ON  44.64589
#
#    Longitude                                    Location  \
# 0  -78.78312  50 km W of Bancroft. Location approximate.
# 1  -77.16640           NE of Madoc. Location approximate
# 2  -77.09972           NE of Madoc. Location approximate
# 3  -76.75339                   Robertson Lake shear zone
# 4  -77.09972           NE of Madoc. Location approximate
#
#                                      Geological_Info    Rock_Type  \
# 0  Central Metasedimentary Belt, Boundary Zone - ...  Metamorphic
# 1  Central Metasedimentary Belt, Elzevir terrane ...  Metamorphic
# 2  Central Metasedimentary Belt, Elzevir terrane ...  Metamorphic
# 3                               Metasedimentary Belt  Metamorphic
# 4  Central Metasedimentary Belt, Elzevir terrane ...  Metamorphic
#
#               Rock_Description  \
# 0                  amphibolite
# 1                  amphibolite
# 2                       gneiss
# 3  amphibolite and mica schist
# 4                       gneiss
#
#                                           References
# 0  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 1  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 2  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...
# 3  Busch, J.P., and van der Pluijm, B.A., 1996, L...
# 4  Cosca, M.A., Sutter, J.F. and Essene, E.J., 19...

# %%
Central_Meta_Belt_ages.Age_Material.unique()
# Out:
# array(['Biotite', 'Hornblende', 'Monazite', 'Rutile', 'Titanite'],
#       dtype=object)

# %%
plt.figure(figsize=(15, 15))
for i in range(len(Central_Meta_Belt_ages.Age_Material.unique())):
    this_material = Central_Meta_Belt_ages[Central_Meta_Belt_ages['Age_Material'] == Central_Meta_Belt_ages.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index,  0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Central_Meta_Belt_ages.Age_Material.unique()[i]], ls='None', label=Central_Meta_Belt_ages.Age_Material.unique()[i])
plt.title('Central Metasedimentary Belt thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()

# %%
plt.figure(figsize=(15, 8))
for i in Central_Meta_Belt_ages.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Central_Meta_Belt_ages[Central_Meta_Belt_ages['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %% [markdown]
# ## Cosca 1991 CGB and CMB Ar thermochron

# %%
Cosca1991a_ages = pd.read_csv('../data/thermochron_compilation/Cosca1991a.csv')
Cosca1991a_ages = Cosca1991a_ages[Cosca1991a_ages['Sample_No'] != 'HL86-7']
Cosca1991a_ages = Cosca1991a_ages[Cosca1991a_ages['Age_Material'] != 'Muscovite']
Cosca1991a_ages = Cosca1991a_ages.sort_values(by=['Age_Material', 'Age']).reset_index(drop=1)
Cosca1991a_ages.head()
# Out:
#   Sample_No  Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 0  MIN86-3A  848           6            6      Ar/Ar            Cooling
# 1    HL86-3  850          20           20      Ar/Ar            Cooling
# 2    SSA-12  875           8            8      Ar/Ar            Cooling
# 3   HL86-2B  897           4            4      Ar/Ar            Cooling
# 4     PSA-2  904           8            8      Ar/Ar            Cooling
#
#       Age_Note Age_Material      Age_Technique Age_Qualifier  \
# 0  amphibolite      Biotite  Ar Furnace-Fusion      Estimate
# 1  amphibolite      Biotite  Ar Furnace-Fusion      Estimate
# 2       gneiss      Biotite    Ar Furnace-Step        Direct
# 3       gneiss      Biotite  Ar Furnace-Fusion      Estimate
# 4       gneiss      Biotite    Ar Furnace-Step        Direct
#
#   Geological_Province Province  Latitude  Longitude  \
# 0  Grenville Province       ON  45.03339  -78.78312
# 1  Grenville Province       ON  44.61256  -77.16640
# 2  Grenville Province       ON  45.58720  -78.50004
# 3  Grenville Province       ON  44.64589  -77.09972
# 4  Grenville Province       ON  45.44172  -80.02066
#
#                                             Location  \
# 0         50 km W of Bancroft. Location approximate.
# 1                  NE of Madoc. Location approximate
# 2  No topographic reference given in report; loca...
# 3                  NE of Madoc. Location approximate
# 4  Location very approximate; not specifically lo...
#
#                                      Geological_Info    Rock_Type  \
# 0  Central Metasedimentary Belt Boundary Zone - u...  Metamorphic
# 1  Central Metasedimentary Belt, Elzevir terrane ...  Metamorphic
# 2  Central Metasedimentary Belt, Algonquin/McClin...  Metamorphic
# 3  Central Metasedimentary Belt, Elzevir terrane ...  Metamorphic
# 4                      Central Gneiss Belt - unknown  Metamorphic
#
#   Rock_Description                                         References
# 0      amphibolite  Cosca, M. A., Sutter, J. F., & Essene, E. J. (...
# 1      amphibolite  Cosca, M. A., Sutter, J. F., & Essene, E. J. (...
# 2           gneiss  Cosca, M. A., Sutter, J. F., & Essene, E. J. (...
# 3           gneiss  Cosca, M. A., Sutter, J. F., & Essene, E. J. (...
# 4           gneiss  Cosca, M. A., Sutter, J. F., & Essene, E. J. (...

# %%
plt.figure(figsize=(10, 10))
for i in range(len(Cosca1991a_ages.Age_Material.unique())):
    this_material = Cosca1991a_ages[Cosca1991a_ages['Age_Material'] == Cosca1991a_ages.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index,  0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Cosca1991a_ages.Age_Material.unique()[i]], ls='None', label=Cosca1991a_ages.Age_Material.unique()[i])
plt.title('Cosca 1991 thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()

# %%
plt.figure(figsize=(15, 8))
for i in Cosca1991a_ages.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Cosca1991a_ages[Cosca1991a_ages['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
# plt.ylim(0, 1200)
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %% [markdown]
# ## Allard Lake and St. Urbain thermochron
# Based on Morisset 2009 U-Pb and Ar

# %%
Allard_Urbain_ages = pd.read_csv('../data/thermochron_compilation/Morisset2009a.csv')
Allard_Urbain_ages = Allard_Urbain_ages.drop(0)
Allard_Urbain_ages = Allard_Urbain_ages.sort_values(by=['Age_Material', 'Age']).reset_index(drop=1)
Allard_Urbain_ages.head()
# Out:
#   Sample_No    Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 0    2033-D  860.3        4.15         4.15      Ar/Ar            Cooling
# 1    2042-A  873.4        2.70         2.70      Ar/Ar            Cooling
# 2  2036-B1B  875.7        2.25         2.25      Ar/Ar            Cooling
# 3   2015-A4  884.4        2.70         2.70      Ar/Ar            Cooling
# 4    2033-D  885.8        2.30         2.30      Ar/Ar            Cooling
#
#    Age_Note Age_Material    Age_Technique Age_Qualifier  ... Province  \
# 0       NaN      Biotite  Ar Furnace-Step        Direct  ...       ON
# 1       NaN      Biotite  Ar Furnace-Step        Direct  ...       ON
# 2       NaN      Biotite  Ar Furnace-Step        Direct  ...       ON
# 3       NaN      Biotite  Ar Furnace-Step        Direct  ...       ON
# 4       NaN      Biotite  Ar Furnace-Step        Direct  ...       ON
#
#   Latitude  Longitude  Location                 Geological_Info Rock_Type  \
# 0  5265524     382455       NaN  Habre-Saint-Pierre anorthosite  Plutonic
# 1  5277212     379295       NaN  Habre-Saint-Pierre anorthosite  Plutonic
# 2  5266680     383090       NaN  Habre-Saint-Pierre anorthosite  Plutonic
# 3  5265611     382943       NaN  Habre-Saint-Pierre anorthosite  Plutonic
# 4  5265524     392455       NaN  Habre-Saint-Pierre anorthosite  Plutonic
#
#   Rock_Description                                         References  \
# 0              NaN  Morisset, C. E., Scoates, J. S., Weis, D., & F...
# 1              NaN  Morisset, C. E., Scoates, J. S., Weis, D., & F...
# 2              NaN  Morisset, C. E., Scoates, J. S., Weis, D., & F...
# 3              NaN  Morisset, C. E., Scoates, J. S., Weis, D., & F...
# 4              NaN  Morisset, C. E., Scoates, J. S., Weis, D., & F...
#
#   min_effective_radius  max_effective_radius
# 0                  250                   500
# 1                  380                   800
# 2                  450                   700
# 3                  100                   500
# 4                  700                   850
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(10, 10))
for i in range(len(Allard_Urbain_ages.Age_Material.unique())):
    this_material = Allard_Urbain_ages[Allard_Urbain_ages['Age_Material'] == Allard_Urbain_ages.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index,  0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Allard_Urbain_ages.Age_Material.unique()[i]], ls='None', label=Allard_Urbain_ages.Age_Material.unique()[i])
plt.title('Lac Allard St. Urbain thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()

# %%
plt.figure(figsize=(15, 8))
for i in Allard_Urbain_ages.Age_Material.unique():
    closure_temp_bounds = closure_temp_bounds_dict[i]
    this_material = Allard_Urbain_ages[Allard_Urbain_ages['Age_Material'] == i]
    plt.errorbar(this_material['Age'], np.full(len(this_material['Age']),closure_temp_bounds[0]), closure_temp_bounds[1], this_material['Error_Plus'], fmt='.',
                 color=color_dict[i], ls='None', label=i)
plt.ylabel('Temperature')
plt.xlabel('Age (Ma)')
plt.ylim(0, 1200)
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %% [markdown]
# ## Frontenac axis dikes whole rock thermochron

# %%
Frontenac_axis_ages = pd.read_csv('../data/thermochron_compilation/Reynolds1978a.csv')
Frontenac_axis_ages = Frontenac_axis_ages.sort_values(by=['Age_Material', 'Age']).reset_index(drop=1)
Frontenac_axis_ages.head()
# Out:
#   Sample_No    Age  Error_Plus  Error_Minus Age_Method Age_Interpretation  \
# 0     K5-2B  871.0        49.9         49.9      Ar/Ar            Cooling
# 1     K3-4B  871.8        46.8         46.8      Ar/Ar            Cooling
# 2      K6-1  885.8        29.3         29.3      Ar/Ar            Cooling
# 3    WF9-2A  904.4        19.9         19.9      Ar/Ar            Cooling
# 4     K4-4A  909.8        23.1         23.1      Ar/Ar            Cooling
#
#        Age_Note Age_Material    Age_Technique  Age_Qualifier  \
# 0  recalculated   Whole Rock  Ar Furnace-Step            NaN
# 1  recalculated   Whole Rock  Ar Furnace-Step            NaN
# 2  recalculated   Whole Rock  Ar Furnace-Step            NaN
# 3  recalculated   Whole Rock  Ar Furnace-Step            NaN
# 4  recalculated   Whole Rock  Ar Furnace-Step            NaN
#
#   Geological_Province Province  Latitude  Longitude  Location Geological_Info  \
# 0  Grenville Province       ON      44.3        -76       NaN       Frontenac
# 1  Grenville Province       ON      44.3        -76       NaN       Frontenac
# 2  Grenville Province       ON      44.3        -76       NaN       Frontenac
# 3  Grenville Province       ON      44.3        -76       NaN       Frontenac
# 4  Grenville Province       ON      44.3        -76       NaN       Frontenac
#
#   Rock_Type Rock_Description  \
# 0  Plutonic          diabase
# 1  Plutonic          diabase
# 2  Plutonic          diabase
# 3  Plutonic          diabase
# 4  Plutonic          diabase
#
#                                           References
# 0  Reynolds, P. H., Olojo, E. O., Stukas, V. J., ...
# 1  Reynolds, P. H., Olojo, E. O., Stukas, V. J., ...
# 2  Reynolds, P. H., Olojo, E. O., Stukas, V. J., ...
# 3  Reynolds, P. H., Olojo, E. O., Stukas, V. J., ...
# 4  Reynolds, P. H., Olojo, E. O., Stukas, V. J., ...

# %%
plt.figure(figsize=(10, 10))
for i in range(len(Frontenac_axis_ages.Age_Material.unique())):
    this_material = Frontenac_axis_ages[Frontenac_axis_ages['Age_Material'] == Frontenac_axis_ages.Age_Material.unique()[i]]
    plt.errorbar(this_material['Age'], this_material.index,  0, this_material['Error_Plus'], fmt='.',
                 color=color_dict[Frontenac_axis_ages.Age_Material.unique()[i]], ls='None', label=Frontenac_axis_ages.Age_Material.unique()[i])
plt.title('Frontenac axis dikes thermochron compilation')
plt.ylabel('Thermochron data count')
plt.xlabel('Age (Ma)')
plt.gca().invert_xaxis()
plt.legend()

# %%
print(np.round([Frontenac_axis_ages['Age'].mean(), Frontenac_axis_ages['Age'].std()], 1)
# Out:
# [892.4  18.7]
